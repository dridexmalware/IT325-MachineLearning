# %% [markdown]
# # **Machine Learning Activities**
#
# This notebook conatins all the activities pertinent to the course "IT325/Machine Learning". Please follow the instructions provided within each item and maintain consistency with the naming conventions when naming files.
#
#
# **Note:**
# - Please be aware that submissions not adhering to the naming convention won't appear in the summary report of submissions. And also, do not create a subfolder that contains all your files.
#
# **Instructor:** Jhun Brian M. Andam
#
# **Email and Office:** jhunbrian.andam@ustp.edu.ph | Bldg. 9-205

# %% [markdown]
# ## **ML Activity 1 | Machine Learning in Different Industries**
#
# Discuss how data mining / machine learning is applied in each area as enumerated below:
#     <ul>
#         <li>Marketing</li>
#         <li>Health Care</li>
#         <li>Education</li>
#         <li>Retail Industry</li>
#         <li>Banking</li>
#     </ul>
#
# **FileName:** SurnameFirstname_MLActivity.pdf

# %% [markdown]
# ## **Laboratory Exercise 1 | Data Preprocessing and the Data Mining Concept**
#
#
# * Complete the assigned notebook
#
# **FileName:** SurnameFirstname_LaboratoryExercise1.ipynb

# %% [markdown]
# ## **Laboratory Exercise 2 | Machine Learning (KNN and DT using Heart Disease Dataset)**
#
#
# * Complete the assigned notebook
# * Please access this <a href="https://drive.google.com/file/d/164iFdL8NQnLzg5yTnoWFKrJfcjjY_mfE/view?usp=sharing">link</a> for the notebook template
#
# **FileName:** SurnameFirstname_LaboratoryExercise2.ipynb

# %% [markdown]
# ## **Lecture Activity 1 | DT Algorithm**
#
#
# * Analyze the resource provided on the decision tree algorithm. Summarize the algorithm in 500 words, detailing how the steps are carried out. Additionally, include your insights and realizations for this model.
#
#
# **FileName:** SurnameFirstname_LectureActivity1.txt

# %% [markdown]
# ## **Lecture Activity 2 | Performance Metrics Use Cases**
#
#
# Cite instances of use-cases in model evaluation where;
#
# - Accuracy
# - Recall
# - Specificity
# - F1 Score
#
# Are the more sensible indicator of model performance.
#
# **FileName:** SurnameFirstname_LectureActivity2.txt

# %% [markdown]
# <h4 style="color:red"><b>PLEASE UPLOAD THE PREVIOUS ACTIVITIES BEFORE MARCH 12 TO ENSURE TIMELINESS</b></h4>

# %% [markdown]
# ## **Lecture Activity 3 | Linear Regression vs. Logistic Regression**
#
# Review the materials about <a href="https://ustep.ustp.edu.ph/mod/folder/view.php?id=563957">Linear Regression and Logistic Regression</a> posted in ustep,  after studying the materials, compose a 100-word essay reflecting on your key takeaways and realizations
#
#
# **FileName:** SurnameFirstname_LectureActivity3.txt
#
# **Due**:
# - IT3R9 and IT3R10: March 27

# %% [markdown]
# ## **Laboratory Exercice 3 | Linear Regression**
#
# - Use this <a href="https://drive.google.com/file/d/1adgUWWnv8N-fZVFIGGfSHlcdlrBT4bWz/view?usp=drive_link">dataset</a> and perform linear regression (simple linear or multiple linear regression) to predict the price.
#
# **FileName:** SurnameFirstname_LaboratoryActivity3.ipynb
#
# **Due:**
#   - IT3R9: April 3
#   - IT3R10: April 4
